# %%
# import dependencies
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
import numpy as np
import pandas as pd
from ucimlrepo import fetch_ucirepo 
from sklearn.model_selection import train_test_split
import models as tests
from sklearn.preprocessing import StandardScaler

# %%
# Read in data as dataframe and show results
df = pd.read_csv('../datasets/winequality-red.csv',sep=';').set_index('residual sugar')
df
# Out:
#                 fixed acidity  volatile acidity  citric acid  chlorides  \
# residual sugar
# 1.9                       7.4             0.700         0.00      0.076
# 2.6                       7.8             0.880         0.00      0.098
# 2.3                       7.8             0.760         0.04      0.092
# 1.9                      11.2             0.280         0.56      0.075
# 1.9                       7.4             0.700         0.00      0.076
# ...                       ...               ...          ...        ...
# 2.0                       6.2             0.600         0.08      0.090
# 2.2                       5.9             0.550         0.10      0.062
# 2.3                       6.3             0.510         0.13      0.076
# 2.0                       5.9             0.645         0.12      0.075
# 3.6                       6.0             0.310         0.47      0.067
#
#                 free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
print(f'null check \n{df.isnull().sum()}')
# Out:
# null check
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Set X and y variables
X = df.drop('quality',axis=1)
y = df['quality']
print(f'X values: \n{X.head()}\n \ny values: \n{y}')
# Out:
# X values:
#                 fixed acidity  volatile acidity  citric acid  chlorides  \
# residual sugar
# 1.9                       7.4              0.70         0.00      0.076
# 2.6                       7.8              0.88         0.00      0.098
# 2.3                       7.8              0.76         0.04      0.092
# 1.9                      11.2              0.28         0.56      0.075
# 1.9                       7.4              0.70         0.00      0.076
#
#                 free sulfur dioxide  total sulfur dioxide  density    pH  \
# residual sugar
# 1.9                            11.0                  34.0   0.9978  3.51
# 2.6                            25.0                  67.0   0.9968  3.20
# 2.3                            15.0                  54.0   0.9970  3.26
# 1.9                            17.0                  60.0   0.9980  3.16
# 1.9                            11.0                  34.0   0.9978  3.51
#
#                 sulphates  alcohol
# ...

# %%
# Split Data into training and test sets
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=13)

# %%
# Use imported 'many_models' function to run through initial models
wine_qt_models1 = tests.many_models(X_train,y_train,X_test,y_test)
# Out:
# Random Forest
# Test Accuracy: 0.67
# balanced test score: 0.3276339916523486
#
# Gradient Boost
# Test Accuracy: 0.625
# balanced test score: 0.32069342450542243
#
# Logistic Regression
# Test Accuracy: 0.58
# balanced test score: 0.2628887931448603
#
# Poly Support Vector
# Test Accuracy: 0.5975
# Balanced test score: 0.25857819619743544
#
# ADA low estimators
# Test Accuracy: 0.5525
# balanced test score: 0.21612210798482798
#
# ADA
# Test Accuracy: 0.5525
# balanced test score: 0.21612210798482798
#
# SVC Sigmoid
# Test Accuracy: 0.5125
# balanced test score: 0.23951210867428455
#                      Trained Score  Test Score  Balanced Trained Score  \
# Model Name
# Random Forest             1.000000      0.6700                1.000000
# Gradient Boosting         0.895746      0.6250                0.901125
# Logistic Regression       0.608007      0.5800                0.317127
# SVC poly                  0.682235      0.5975                0.406597
# ...
