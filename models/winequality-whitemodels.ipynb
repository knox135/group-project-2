# %%
# import dependencies
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
import numpy as np
import pandas as pd
from ucimlrepo import fetch_ucirepo 
from sklearn.model_selection import train_test_split
import models as tests
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('../datasets/winequality-red.csv',sep=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
print(f'null check \n{df.isnull().sum()}')
# Out:
# null check
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
X = df.drop('quality',axis=1)
y = df['quality']
print(f'X values: \n{X.head()}\n \ny values: \n{y}')
# Out:
# X values:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4
#
# y values:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=13)

# %%
# ravel the data to flatten it for models
y_train = y_train.values.ravel()
y_test = y_test.values.ravel()
# Scale X data
scaled = StandardScaler()

X_train = scaled.fit_transform(X_train)
X_test = scaled.transform(X_test)
print(f'y_train: {y_train} \n X_train:{X_train}')
# Out:
# y_train: [5 7 6 ... 5 5 6]
#  X_train:[[-0.36140493 -0.77224544 -0.77928694 ... -0.9652767  -0.97244362
#   -0.96121652]
#  [-0.24675365  0.63769215 -1.34246587 ...  0.1942158   0.4963157
#    1.17258202]
#  [-0.82001005  1.12574747 -1.2400697  ...  0.90279455 -0.1499384
#    0.98703432]
#  ...
#  [ 0.78510787 -1.15184403  1.3710326  ... -0.1922817   0.96631869
#   -0.77566882]
#  [-0.59070749 -0.82647381 -0.31850418 ...  0.12979955 -1.08994437
#   -0.86844267]
#  [ 2.33290015 -0.22996175  1.57582494 ... -0.9652767   2.02382541
#    0.98703432]]

# %%
models1 = tests.many_models(X_train,y_train,X_test,y_test)
# Out:
# Random Forest
# Test Accuracy: 0.68
# balanced test score: 0.32920256756612126
#
# Gradient Boost
# Test Accuracy: 0.625
# balanced test score: 0.3043480543284533
#
# Logistic Regression
# Test Accuracy: 0.5825
# balanced test score: 0.27804030829637544
#
# Poly Support Vector
# Test Accuracy: 0.59
# Balanced test score: 0.2552669379192897
#
# ADA low estimators
# Test Accuracy: 0.5525
# balanced test score: 0.21612210798482798
#
# ADA
# Test Accuracy: 0.5525
# balanced test score: 0.21612210798482798
#
# SVC Sigmoid
# Test Accuracy: 0.49
# balanced test score: 0.22626371539432064
#                      Trained Score  Test Score  Balanced Trained Score  \
# Model Name
# Random Forest             1.000000      0.6800                1.000000
# Gradient Boosting         0.898249      0.6250                0.907831
# Logistic Regression       0.615513      0.5825                0.327136
# SVC poly                  0.691410      0.5900                0.448831
# SVC sigmoid               0.482902      0.4900                0.222654
# ADA Low Estimators        0.552961      0.5525                0.223144
# ADA boost                 0.552961      0.5525                0.223144
#
#                      Balanced Test Score  Balanced Difference
# Model Name
# Random Forest                   0.329203             0.670797
# Gradient Boosting               0.304348             0.603483
# Logistic Regression             0.278040             0.049096
# SVC poly                        0.255267             0.193564
# SVC sigmoid                     0.226264            -0.003609
# ADA Low Estimators              0.216122             0.007022
# ADA boost                       0.216122             0.007022
