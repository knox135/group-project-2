# %%
# import dependencies
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
import numpy as np
import pandas as pd
from ucimlrepo import fetch_ucirepo 
from sklearn.model_selection import train_test_split
import models as tests
from sklearn.preprocessing import StandardScaler

# %%
wineqt_df = pd.read_csv('../datasets/wineQT.csv')
wineqt_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
print(f'null check \n{wineqt_df.isnull().sum()}')
# Out:
# null check
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
X = wineqt_df.drop(columns=['quality','Id'])
y = wineqt_df['quality']
print(f'X values: \n{X.head()}\n \ny values: \n{y}')
# Out:
# X values:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=13)

# %%
# ravel the data to flatten it for models
y_train = y_train.ravel()
y_test = y_test.ravel()

scaled = StandardScaler()
X_train = scaled.fit_transform(X_train)
X_test = scaled.transform(X_test)

# %%
wine_qt_models1 = tests.many_models(X_train,y_train,X_test,y_test)
# Out:
# Random Forest
# Test Accuracy: 0.6713286713286714
# balanced test score: 0.38801894543521337
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:2394: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:2394: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# Gradient Boost
# Test Accuracy: 0.6363636363636364
# balanced test score: 0.38939152288434586
#
# Logistic Regression
# Test Accuracy: 0.6048951048951049
# balanced test score: 0.3322845681697356
#
# Poly Support Vector
# Test Accuracy: 0.6013986013986014
# Balanced test score: 0.32353680344110963
#
# ADA low estimators
# Test Accuracy: 0.4965034965034965
# balanced test score: 0.32214731042482236
#
# ADA
# Test Accuracy: 0.44755244755244755
# balanced test score: 0.3127905852786236
#
# ...
