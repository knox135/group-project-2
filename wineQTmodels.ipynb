# %%
# import dependencies
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
import numpy as np
import pandas as pd
from ucimlrepo import fetch_ucirepo 
from sklearn.model_selection import train_test_split
import models as tests
from sklearn.preprocessing import StandardScaler

# %%
wineqt_df = pd.read_csv('./datasets/wineQT.csv')
wineqt_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
X = wineqt_df.drop(columns=['quality','Id'])
y = wineqt_df['quality']#.values.reshape(-1,1)
X.head(),y
# Out:
# (   fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
#  0            7.4              0.70         0.00             1.9      0.076
#  1            7.8              0.88         0.00             2.6      0.098
#  2            7.8              0.76         0.04             2.3      0.092
#  3           11.2              0.28         0.56             1.9      0.075
#  4            7.4              0.70         0.00             1.9      0.076
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
#  0                 11.0                  34.0   0.9978  3.51       0.56
#  1                 25.0                  67.0   0.9968  3.20       0.68
#  2                 15.0                  54.0   0.9970  3.26       0.65
#  3                 17.0                  60.0   0.9980  3.16       0.58
#  4                 11.0                  34.0   0.9978  3.51       0.56
#
#     alcohol
#  0      9.4
#  1      9.8
#  2      9.8
#  3      9.8
#  4      9.4  ,
#  0       5
#  1       5
#  2       5
#  3       6
#  4       5
#         ..
#  1138    6
#  1139    6
#  1140    5
#  1141    6
#  1142    5
#  Name: quality, Length: 1143, dtype: int64)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, random_state=42)

# %%
# ravel the data to flatten it for models
y_train = y_train.ravel()
y_test = y_test.ravel()

scaled = StandardScaler()
X_train = scaled.fit_transform(X_train)
X_test = scaled.transform(X_test)

# %%
wine_qt_models1 = tests.many_models(X_train,y_train,X_test,y_test)
# Out:
# Random Forest
# balanced test score: 0.41020904229460375
# classification report:
#                precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         7
#            5       0.72      0.79      0.75       121
#            6       0.66      0.67      0.66       121
#            7       0.69      0.59      0.63        34
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.69       286
#    macro avg       0.41      0.41      0.41       286
# weighted avg       0.66      0.69      0.67       286
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:2394: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:2394: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Gradient Boost
# balanced test score: 0.37272727272727274
#
#  classification report:
#                precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         7
#            5       0.72      0.72      0.72       121
#            6       0.62      0.64      0.63       121
#            7       0.59      0.50      0.54        34
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.64       286
#    macro avg       0.32      0.31      0.32       286
# weighted avg       0.64      0.64      0.64       286
#
# Logistic Regression
# balanced test score: 0.36426835196888674
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         7
#            5       0.69      0.73      0.71       121
#            6       0.61      0.65      0.63       121
#            7       0.56      0.44      0.49        34
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.64       286
#    macro avg       0.31      0.30      0.30       286
# weighted avg       0.61      0.64      0.62       286
#
# Poly Support Vector
# balanced test score: 0.3315508021390375
# classification report:
#                precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         7
#            5       0.66      0.76      0.71       121
#            6       0.57      0.60      0.58       121
#            7       0.62      0.29      0.40        34
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.61       286
#    macro avg       0.37      0.33      0.34       286
# weighted avg       0.59      0.61      0.59       286
#
# ADA low estimators
# balanced test score: 0.33840544482255713
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# classification report:
#                precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         7
#            5       0.62      0.77      0.69       121
#            6       0.56      0.31      0.40       121
#            7       0.32      0.62      0.42        34
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.53       286
#    macro avg       0.30      0.34      0.30       286
# weighted avg       0.54      0.53      0.51       286
#
# ADA
# balanced test score: 0.32630043753038407
# classification report:
#                precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         7
#            5       0.74      0.62      0.68       121
#            6       0.56      0.31      0.40       121
#            7       0.21      0.71      0.32        34
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.48       286
#    macro avg       0.30      0.33      0.28       286
# weighted avg       0.58      0.48      0.49       286
#
# SVC Sigmoid
# balanced test score: 0.3051045211473019
# classification report:
#                precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         7
#            5       0.63      0.64      0.64       121
#            6       0.55      0.59      0.57       121
#            7       0.37      0.29      0.33        34
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.56       286
#    macro avg       0.31      0.31      0.31       286
# weighted avg       0.54      0.56      0.55       286
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:2394: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:2394: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
