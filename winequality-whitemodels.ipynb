# %%
# import dependencies
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
import numpy as np
import pandas as pd
from ucimlrepo import fetch_ucirepo 
from sklearn.model_selection import train_test_split
import models as tests
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('./datasets/winequality-red.csv',sep=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, random_state=42)

# %%
# ravel the data to flatten it for models
y_train = y_train.values.ravel()
y_test = y_test.values.ravel()
# Scale X data
scaled = StandardScaler()
X_train = scaled.fit_transform(X_train)
X_test = scaled.transform(X_test)

# %%
models1 = tests.many_models(X_train,y_train,X_test,y_test)
# Out:
# Random Forest
# balanced test score: 0.35452315781471055
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         9
#            4       0.88      0.12      0.22        57
#            5       0.68      0.75      0.71       518
#            6       0.66      0.74      0.70       738
#            7       0.69      0.55      0.61       259
#            8       0.88      0.33      0.47        43
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.67      1625
#    macro avg       0.54      0.35      0.39      1625
# weighted avg       0.68      0.67      0.66      1625
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Gradient Boost
# balanced test score: 0.29575240158064203
#
#  classification report:
#                precision    recall  f1-score   support
#
#            3       0.12      0.11      0.12         9
#            4       0.24      0.07      0.11        57
#            5       0.61      0.64      0.62       518
#            6       0.58      0.70      0.63       738
#            7       0.56      0.35      0.43       259
#            8       0.64      0.21      0.32        43
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.58      1625
#    macro avg       0.39      0.30      0.32      1625
# weighted avg       0.57      0.58      0.57      1625
#
# Logistic Regression
# balanced test score: 0.21109735918098288
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         9
#            4       0.00      0.00      0.00        57
#            5       0.54      0.60      0.57       518
#            6       0.53      0.67      0.59       738
#            7       0.50      0.20      0.29       259
#            8       0.00      0.00      0.00        43
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.53      1625
#    macro avg       0.22      0.21      0.21      1625
# weighted avg       0.49      0.53      0.50      1625
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Poly Support Vector
# balanced test score: 0.22465524391069963
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.33      0.11      0.17         9
#            4       0.50      0.02      0.03        57
#            5       0.59      0.53      0.56       518
#            6       0.52      0.75      0.61       738
#            7       0.55      0.16      0.25       259
#            8       0.00      0.00      0.00        43
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.54      1625
#    macro avg       0.35      0.22      0.23      1625
# weighted avg       0.53      0.54      0.50      1625
#
# ADA low estimators
# balanced test score: 0.15018677213799167
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.00      0.11      0.01         9
#            4       0.00      0.00      0.00        57
#            5       0.43      0.57      0.49       518
#            6       0.48      0.37      0.42       738
#            7       0.00      0.00      0.00       259
#            8       0.00      0.00      0.00        43
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.35      1625
#    macro avg       0.13      0.15      0.13      1625
# weighted avg       0.36      0.35      0.35      1625
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ADA
# balanced test score: 0.15018677213799167
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.00      0.11      0.01         9
#            4       0.00      0.00      0.00        57
#            5       0.43      0.57      0.49       518
#            6       0.48      0.37      0.42       738
#            7       0.00      0.00      0.00       259
#            8       0.00      0.00      0.00        43
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.35      1625
#    macro avg       0.13      0.15      0.13      1625
# weighted avg       0.36      0.35      0.35      1625
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SVC Sigmoid
# balanced test score: 0.1826886916660415
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         9
#            4       0.08      0.11      0.09        57
#            5       0.43      0.51      0.47       518
#            6       0.46      0.47      0.47       738
#            7       0.25      0.17      0.21       259
#            8       0.09      0.02      0.04        43
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.41      1625
#    macro avg       0.19      0.18      0.18      1625
# weighted avg       0.39      0.41      0.40      1625
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
